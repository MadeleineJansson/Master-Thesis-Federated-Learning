# %% [markdown]
# # Plot of average loss as well as AUPCR
# ### Non-IID

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Functions

# %%
def loss_curve(list_vectors, legend_vec, epochs, txt='none'):
    """ Plot loss against epochs.
    IN: list_vec (list), epochs (list int)
    OUT: - 
    """
    for vec in list_vectors:
        plt.plot(vec)
    
    #plt.ylim([-1, max(vec)])
    #plt.xlim([0, epochs/10])
    plt.ylabel('Average loss')
    plt.xlabel('Epoch')
    plt.legend(legend_vec, loc='upper right')
    plt.show()
    
    if not txt == 'none':
        for index, l in enumerate(list_vectors):
            print('Min value', str(index+2), txt, ': ', str(min(l)))

# %%
def aupcr(list_vectors, legend_vec, epochs, txt='none'):
    """ Plot AUPCR against epochs.
    IN: list_vec (list), epochs (list int)
    OUT: - 
    """
    for vec in list_vectors:
        plt.plot(vec)

    plt.ylabel('Area under Profile Curve ratio (AUPCR)')
    plt.xlabel('Epoch')
    plt.legend(legend_vec, loc='upper left')
    plt.show() 
    
    if not txt == 'none':
        for index, l in enumerate(list_vectors):
            print('Max value', str(index+2), txt, ': ', str(max(l)))

# %%
t = 'none'
if not t == 'none':
    print('j')

# %%
legend_loc_it = ['2 local iterations', '3 local iterations']
txt_loc_it = 'local iterations'

legend_random_clients = ['2 random clients', '3 random clients', '4 random clients']
txt_rand_clients = 'random clients'

legend_batch = ['32', '64', '128']

# %% [markdown]
# ### Batch size 32
#
# ### 2 random clients

# %% [markdown]
# Average loss

# %%
loss_2_local_it = [0.00251878, 0.0022698, 0.00241231, 0.00238891, 0.00230123, 0.00237953]
loss_3_local_it = [0.00294891, 0.00244978, 0.00250128, 0.00239083, 0.00258407, 0.0024644]
list_losses = [loss_2_local_it, loss_3_local_it]

loss_curve(list_losses, legend_loc_it, 60, txt_loc_it)
# Out:
# Min value 2 local iterations :  0.0022698
# Min value 3 local iterations :  0.00239083

# %% [markdown]
# AUPCR

# %%
aupcr_2_local_it = [0.7919492266, 0.7966210448, 0.7741503203, 0.761823259, 0.7839582294, 0.7609850301]
aupcr_3_local_it = [0.7863491592, 0.7893737175, 0.7822782476, 0.7870357894, 0.7727429333, 0.776073228]
list_aupcr = [aupcr_2_local_it, aupcr_3_local_it]

aupcr(list_aupcr, legend_loc_it, 60, txt_loc_it)
# Out:
# Max value 2 local iterations :  0.7966210448
# Max value 3 local iterations :  0.7893737175

# %% [markdown]
# ### 3 random clients

# %% [markdown]
# Average loss

# %%
loss_2_local_it = [0.00248506, 0.00233758, 0.00243429, 0.00227483, 0.00234839, 0.0023903]
loss_3_local_it = [0.00249018, 0.00238929, 0.00242964, 0.00237406, 0.0024297, 0.00249568]
list_losses = [loss_2_local_it, loss_3_local_it]

loss_curve(list_losses, legend_loc_it, 60, txt_loc_it)
# Out:
# Min value 2 local iterations :  0.00227483
# Min value 3 local iterations :  0.00237406

# %% [markdown]
# AUPCR

# %%
aupcr_2_local_it = [0.7841316162, 0.7917339122, 0.7894330807, 0.7906242478, 0.7907395049, 0.7891298797]
aupcr_3_local_it = [0.7861752974, 0.7867634424, 0.7744755243, 0.7763847193, 0.7644571723, 0.7658230946]
list_aupcr = [aupcr_2_local_it, aupcr_3_local_it]

aupcr(list_aupcr, legend_loc_it, 60, txt_loc_it)
# Out:
# Max value 2 local iterations :  0.7917339122
# Max value 3 local iterations :  0.7867634424

# %% [markdown]
# ### 4 random clients

# %% [markdown]
# Average loss

# %%
loss_2_local_it = [0.00528726, 0.00309592, 0.00266944, 0.00257064, 0.00256092, 0.00256519]
loss_3_local_it = [0.0024249, 0.00235691, 0.00239011, 0.00237754, 0.00242815, 0.00243149]
list_losses = [loss_2_local_it, loss_3_local_it]

loss_curve(list_losses, legend_loc_it, 60, txt_loc_it)
# Out:
# Min value 2 local iterations :  0.00256092
# Min value 3 local iterations :  0.00235691

# %% [markdown]
# AUPCR

# %%
aupcr_2_local_it = [0.684500168, 0.7478551376, 0.7671878069, 0.761053897, 0.7569463719, 0.7703613171]
aupcr_3_local_it = [0.7803647368, 0.7862735765, 0.7819158213, 0.7772509435, 0.773095922, 0.7715682134]
list_aupcr = [aupcr_2_local_it, aupcr_3_local_it]

aupcr(list_aupcr, legend_loc_it, 60, txt_loc_it)
# Out:
# Max value 2 local iterations :  0.7703613171
# Max value 3 local iterations :  0.7862735765

# %% [markdown]
# ### 2 local iterations

# %% [markdown]
# Average loss

# %%
loss_2_random_clients = [0.00251878, 0.0022698, 0.00241231, 0.00238891, 0.00230123, 0.00237953]
loss_3_random_clients = [0.00248506, 0.00233758, 0.00243429, 0.00227483, 0.00234839, 0.0023903]
loss_4_random_clients = [0.00528726, 0.00309592, 0.00266944, 0.00257064, 0.00256092, 0.00256519]
list_losses = [loss_2_random_clients, loss_3_random_clients, loss_4_random_clients]

loss_curve(list_losses, legend_random_clients, 60, txt_rand_clients)
# Out:
# Min value 2 random clients :  0.0022698
# Min value 3 random clients :  0.00227483
# Min value 4 random clients :  0.00256092

# %% [markdown]
# AUPCR

# %%
aupcr_2_random_clients = [0.7919492266, 0.7966210448, 0.7741503203, 0.761823259, 0.7839582294, 0.7609850301]
aupcr_3_random_clients = [0.7841316162, 0.7917339122, 0.7894330807, 0.7906242478, 0.7907395049, 0.7891298797]
aupcr_4_random_clients = [0.684500168, 0.7478551376, 0.7671878069, 0.761053897, 0.7569463719, 0.7703613171]
list_aupcr = [aupcr_2_random_clients, aupcr_3_random_clients, aupcr_4_random_clients]

aupcr(list_aupcr, legend_random_clients, 60, txt_rand_clients)
# Out:
# Max value 2 random clients :  0.7966210448
# Max value 3 random clients :  0.7917339122
# Max value 4 random clients :  0.7703613171

# %% [markdown]
# ### 3 local iterations

# %% [markdown]
# Average loss

# %%
loss_2_random_clients = [0.00294891, 0.00244978, 0.00250128, 0.00239083, 0.00258407, 0.0024644]
loss_3_random_clients = [0.00249018, 0.00238929, 0.00242964, 0.00237406, 0.0024297, 0.00249568]
loss_4_random_clients = [0.0024249, 0.00235691, 0.00239011, 0.00237754, 0.00242815, 0.00243149]
list_losses = [loss_2_random_clients, loss_3_random_clients, loss_4_random_clients]

loss_curve(list_losses, legend_random_clients, 60, txt_rand_clients)
# Out:
# Min value 2 random clients :  0.00239083
# Min value 3 random clients :  0.00237406
# Min value 4 random clients :  0.00235691

# %% [markdown]
# AUPCR

# %%
aupcr_2_random_clients = [0.7863491592, 0.7893737175, 0.7822782476, 0.7870357894, 0.7727429333, 0.776073228]
aupcr_3_random_clients = [0.7861752974, 0.7867634424, 0.7744755243, 0.7763847193, 0.7644571723, 0.7658230946]
aupcr_4_random_clients = [0.7803647368, 0.7862735765, 0.7819158213, 0.7772509435, 0.773095922, 0.7715682134]
list_aupcr = [aupcr_2_random_clients, aupcr_3_random_clients, aupcr_4_random_clients]

aupcr(list_aupcr, legend_random_clients, 60, txt_rand_clients)
# Out:
# Max value 2 random clients :  0.7893737175
# Max value 3 random clients :  0.7867634424
# Max value 4 random clients :  0.7862735765

# %% [markdown]
# ### Batch size 64

# %% [markdown]
# ### 2 random clients

# %% [markdown]
# Average loss

# %%
loss_32 = [0.0036610445462421405, 0.002969886839302836, 0.002892815507208566, 0.0025932991385990223, 0.0025399332494529525, 
           0.002438744983837249, 0.002210675631765856, 0.002219364229230175, 0.0022008766837353327, 0.002236379931791512, 
           0.0023514461227168255, 0.0022915391590854024, 0.0022373216947563983, 0.0023252208129377373, 0.0023173561864756505, 
           0.00240757625526075]
loss_64 = [0.00362241, 0.00297225, 0.00285269, 0.00252388, 0.00233907, 0.00242061, 0.00227935, 0.00234113, 0.00239213, 0.00227175,
           0.00238252, 0.00238467, 0.00239096, 0.0024932, 0.00239934, 0.00245711]
loss_128 = [0.00719713, 0.00634625, 0.00557677, 0.00421161, 0.00325146, 0.00290259, 0.00265934, 0.00265255, 0.00254936, 0.00241414, 0.00237812,
            0.00236268, 0.00240811, 0.0023870, 0.002412, 0.00232813]
list_losses = [loss_32, loss_64, loss_128]

loss_curve(list_losses, legend_batch, 80)

# %% [markdown]
# AUPCR

# %%
aupcr_32 = [0.7555693597165286, 0.7771490434043733, 0.7808448587954565, 0.7861447729929101, 0.7877714470609476, 0.7905324905186147, 
            0.7941237839992992, 0.7952305247422661, 0.7956094543078689, 0.7951126343970268, 0.794928359375748, 0.7962560963336017, 
            0.793176109784248, 0.7955833144505151, 0.7833563421126803, 0.7947737772353055]
aupcr_64 = [0.7568825403, 0.7713607414, 0.7826663495, 0.7898506653, 0.7908070034, 0.791022632, 0.7933583799, 0.7926902526, 0.7855998977, 
            0.7945540312, 0.7899883906, 0.7858759765, 0.7876932287, 0.7517368854, 0.7813719746, 0.750568092]
aupcr_128 = [0.6024272174, 0.5883773453, 0.6984128175, 0.7417679423, 0.7559730218, 0.7588778347, 0.7656526885, 0.7681947664, 0.7738088889, 
             0.7805340452, 0.7821237434, 0.783332237, 0.7841132091, 0.7853042151, 0.7846917646, 0.7876900082]
list_aupcr = [aupcr_32, aupcr_64, aupcr_128]

aupcr(list_aupcr, legend_batch, 80)

# %% [markdown]
# ### 3 random clients

# %% [markdown]
# Average loss

# %%
loss_32 = [0.003997172645366522, 0.002933291454047313, 0.0026724222226411462, 0.002514697626907256, 0.002567193980806029, 
            0.0025494999352919886, 0.002540665647360702, 0.0025818786744146944, 0.002516022162904504, 0.002612647272828048, 
            0.0025903908142381796, 0.00261197385852782, 0.0026136448739496414, 0.002601025158557332, 0.002653034934383493, 
            0.002664543633970411]
loss_64 = [0.00528709, 0.00323729, 0.00278935, 0.00259273, 0.00253779, 0.00242944, 0.0023157, 0.0023983, 0.00242197, 0.00234404, 0.00239607,
           0.00238752, 0.00245327, 0.00245472, 0.00247062, 0.0024255]
loss_128 = [0.00757209, 0.0042578, 0.00343249, 0.00302938, 0.00283486, 0.00276655, 0.00269455, 0.00267305, 0.00258827, 0.00254626, 
             0.00245743, 0.00245452, 0.00245964, 0.00250537, 0.00249772, 0.00249489]
list_losses = [loss_32, loss_64, loss_128]

loss_curve(list_losses, legend_batch, 80)

# %% [markdown]
# AUPCR

# %%
aupcr_32 = [0.7179881907990183, 0.7573668775813258, 0.7707511362015166, 0.7762898023723567, 0.7805987186337425, 
            0.7814652038370857, 0.7792772806143535, 0.7782951014393593, 0.7777419312870208, 0.7728903324414149, 
            0.7724220530819169, 0.7695054039509105, 0.7705155756407226, 0.7665315844115635, 0.7605627024915248, 0.7621421320632564]
aupcr_64 = [0.7198326946, 0.7439933222, 0.7593364704, 0.774004886, 0.7792726518, 0.783354081, 0.7858468792, 0.7857820129, 0.7834850283,
            0.7863738942, 0.7852512839, 0.7853239741, 0.7817192808, 0.7807319439, 0.778184909, 0.7823903333]
aupcr_128 = [0.7242808556, 0.7592681174, 0.7757615763, 0.7807386356, 0.7866690614, 0.78669354, 0.7877925602, 0.7881178091, 0.7884414282, 
             0.7876282824, 0.7881954338, 0.7898129616, 0.7910507943, 0.7922969626, 0.7931253315, 0.7941873671]
list_aupcr = [aupcr_32, aupcr_64, aupcr_128]

aupcr(list_aupcr, legend_batch, 80)

# %% [markdown]
# ### 4 random clients

# %% [markdown]
# Average loss

# %%
loss_32 = [0.003593299032832582, 0.0030378146572690567, 0.002829896678190154, 0.0026799505309947234, 0.002603823951131124, 
            0.002537783877908777, 0.00249382345340871, 0.0024735198908251, 0.0025030651555146112, 0.0024269384063537506, 
            0.002462223559866492, 0.0024998871663199566, 0.0024941076429001803, 0.0024790915418200056, 0.0025092857602750456, 
            0.0024859558381017843]
loss_64 = [0.00398898, 0.00292261, 0.00266274, 0.00254941, 0.0024802, 0.0024358, 0.00238839, 0.00236849, 0.00235629, 0.00233716, 0.00232406, 
           0.0023079, 0.0023048, 0.00229148, 0.00228666, 0.00227256]
loss_128 = [0.00851676, 0.00487506, 0.00374082, 0.00325386, 0.00303009, 0.0028254, 0.00270838, 0.00263276, 0.00257648, 0.00253619, 
            0.00250375, 0.002475, 0.00245365, 0.00243493, 0.00242593, 0.0024149]
list_losses = [loss_32, loss_64, loss_128]

loss_curve(list_losses, legend_batch, 80)

# %% [markdown]
# AUPCR

# %%
aupcr_32 = [0.753688661797193, 0.7611102952473862, 0.7716043143665288, 0.7735258933134928, 0.7568638145722265, 0.7561646682073669, 
            0.756407395348338, 0.755163109426194, 0.7566846058502072, 0.7534157611680307, 0.7531226705742099, 0.7508404259707339, 
            0.7464043561008784, 0.7458077373537543, 0.7457569587006475, 0.7421319852086666]
aupcr_64 = [0.7663711109, 0.775113119, 0.7798089491, 0.7819170718, 0.7824045967, 0.7829395265, 0.7847119958, 0.7831418025, 0.7813004729, 
            0.7791420325, 0.7756163321, 0.774434085, 0.7665152606, 0.7614562786, 0.7577349104, 0.7557042969]
aupcr_128 = [0.6985694371, 0.7472848238, 0.7609272314, 0.765062388, 0.7707776747, 0.7753489717, 0.7778797723, 0.7799301029, 0.7824811155, 
             0.7837271045, 0.7849953253, 0.7858765965, 0.788223167, 0.7879093632, 0.7886132852, 0.7890399285]
list_aupcr = [aupcr_32, aupcr_64, aupcr_128]

aupcr(list_aupcr, legend_batch, 80)

# %% [markdown]
# ### Comparison between 2, 3 and 4 random clients

# %%
legend_comp_clients = ['32:2', '64:2', '128:2', '32:3', '64:3', '128:3', '32:4', '64:4', '128:4']
legend_clients = ['2', '3', '4']

# %% [markdown]
# Average losses

# %%
loss_32_2 = [0.0036610445462421405, 0.002969886839302836, 0.002892815507208566, 0.0025932991385990223, 0.0025399332494529525, 
             0.002438744983837249, 0.002210675631765856, 0.002219364229230175, 0.0022008766837353327, 0.002236379931791512,
             0.0023514461227168255, 0.0022915391590854024, 0.0022373216947563983, 0.0023252208129377373, 0.0023173561864756505, 
             0.00240757625526075]
loss_64_2 = [0.00362241, 0.00297225, 0.00285269, 0.00252388, 0.00233907, 0.00242061, 0.00227935, 0.00234113, 0.00239213, 0.00227175,
             0.00238252, 0.00238467, 0.00239096, 0.0024932, 0.00239934, 0.00245711]

loss_128_2 = [0.00719713, 0.00634625, 0.00557677, 0.00421161, 0.00325146, 0.00290259, 0.00265934, 0.00265255, 0.00254936, 0.00241414, 0.00237812,
              0.00236268, 0.00240811, 0.0023870, 0.002412, 0.00232813]

loss_32_3 = [0.003997172645366522, 0.002933291454047313, 0.0026724222226411462, 0.002514697626907256, 0.002567193980806029, 
             0.0025494999352919886, 0.002540665647360702, 0.0025818786744146944, 0.002516022162904504, 0.002612647272828048, 
             0.0025903908142381796, 0.00261197385852782, 0.0026136448739496414, 0.002601025158557332, 0.002653034934383493, 
             0.002664543633970411]
loss_64_3 = [0.00528709, 0.00323729, 0.00278935, 0.00259273, 0.00253779, 0.00242944, 0.0023157, 0.0023983, 0.00242197, 0.00234404, 0.00239607,
             0.00238752, 0.00245327, 0.00245472, 0.00247062, 0.0024255]
loss_128_3 = [0.00757209, 0.0042578, 0.00343249, 0.00302938, 0.00283486, 0.00276655, 0.00269455, 0.00267305, 0.00258827, 0.00254626, 
              0.00245743, 0.00245452, 0.00245964, 0.00250537, 0.00249772, 0.00249489]

loss_32_4 = [0.003593299032832582, 0.0030378146572690567, 0.002829896678190154, 0.0026799505309947234, 0.002603823951131124, 
             0.002537783877908777, 0.00249382345340871, 0.0024735198908251, 0.0025030651555146112, 0.0024269384063537506, 
             0.002462223559866492, 0.0024998871663199566, 0.0024941076429001803, 0.0024790915418200056, 0.0025092857602750456, 
             0.0024859558381017843]
loss_64_4 = [0.00398898, 0.00292261, 0.00266274, 0.00254941, 0.0024802, 0.0024358, 0.00238839, 0.00236849, 0.00235629, 0.00233716, 0.00232406, 
             0.0023079, 0.0023048, 0.00229148, 0.00228666, 0.00227256]
loss_128_4 = [0.00851676, 0.00487506, 0.00374082, 0.00325386, 0.00303009, 0.0028254, 0.00270838, 0.00263276, 0.00257648, 0.00253619, 
              0.00250375, 0.002475, 0.00245365, 0.00243493, 0.00242593, 0.0024149]

list_losses = [loss_32_2, loss_64_2, loss_128_2, loss_32_3, loss_64_3, loss_128_3, loss_32_4, loss_64_4, loss_128_4]

loss_curve(list_losses, legend_comp_clients, 80)

# %% [markdown]
# 32

# %%
list_loss_32 = [loss_32_2, loss_32_3, loss_32_4]
loss_curve(list_loss_32, legend_clients, 80)

# %% [markdown]
# 64

# %%
list_loss_64 = [loss_64_2, loss_64_3, loss_64_4]
loss_curve(list_loss_64, legend_clients, 80)

# %% [markdown]
# 128

# %%
list_loss_128 = [loss_128_2, loss_128_3, loss_128_4]
loss_curve(list_loss_128, legend_clients, 80)

# %% [markdown]
# AUPCR

# %%
aupcr_32_2 = [0.7555693597165286, 0.7771490434043733, 0.7808448587954565, 0.7861447729929101, 0.7877714470609476, 0.7905324905186147, 
              0.7941237839992992, 0.7952305247422661, 0.7956094543078689, 0.7951126343970268, 0.794928359375748, 0.7962560963336017, 
              0.793176109784248, 0.7955833144505151, 0.7833563421126803, 0.7947737772353055]
aupcr_64_2 = [0.7568825403, 0.7713607414, 0.7826663495, 0.7898506653, 0.7908070034, 0.791022632, 0.7933583799, 0.7926902526, 0.7855998977, 
              0.7945540312, 0.7899883906, 0.7858759765, 0.7876932287, 0.7517368854, 0.7813719746, 0.750568092]
aupcr_128_2 = [0.6024272174, 0.5883773453, 0.6984128175, 0.7417679423, 0.7559730218, 0.7588778347, 0.7656526885, 0.7681947664, 0.7738088889, 
               0.7805340452, 0.7821237434, 0.783332237, 0.7841132091, 0.7853042151, 0.7846917646, 0.7876900082]

aupcr_32_3 = [0.7179881907990183, 0.7573668775813258, 0.7707511362015166, 0.7762898023723567, 0.7805987186337425, 
              0.7814652038370857, 0.7792772806143535, 0.7782951014393593, 0.7777419312870208, 0.7728903324414149, 
              0.7724220530819169, 0.7695054039509105, 0.7705155756407226, 0.7665315844115635, 0.7605627024915248, 0.7621421320632564]
aupcr_64_3 = [0.7198326946, 0.7439933222, 0.7593364704, 0.774004886, 0.7792726518, 0.783354081, 0.7858468792, 0.7857820129, 0.7834850283,
              0.7863738942, 0.7852512839, 0.7853239741, 0.7817192808, 0.7807319439, 0.778184909, 0.7823903333]
aupcr_128_3 = [0.7242808556, 0.7592681174, 0.7757615763, 0.7807386356, 0.7866690614, 0.78669354, 0.7877925602, 0.7881178091, 0.7884414282, 
               0.7876282824, 0.7881954338, 0.7898129616, 0.7910507943, 0.7922969626, 0.7931253315, 0.7941873671]

aupcr_32_4 = [0.753688661797193, 0.7611102952473862, 0.7716043143665288, 0.7735258933134928, 0.7568638145722265, 0.7561646682073669, 
              0.756407395348338, 0.755163109426194, 0.7566846058502072, 0.7534157611680307, 0.7531226705742099, 0.7508404259707339, 
              0.7464043561008784, 0.7458077373537543, 0.7457569587006475, 0.7421319852086666]
aupcr_64_4 = [0.7663711109, 0.775113119, 0.7798089491, 0.7819170718, 0.7824045967, 0.7829395265, 0.7847119958, 0.7831418025, 0.7813004729, 
              0.7791420325, 0.7756163321, 0.774434085, 0.7665152606, 0.7614562786, 0.7577349104, 0.7557042969]
aupcr_128_4 = [0.6985694371, 0.7472848238, 0.7609272314, 0.765062388, 0.7707776747, 0.7753489717, 0.7778797723, 0.7799301029, 0.7824811155, 
               0.7837271045, 0.7849953253, 0.7858765965, 0.788223167, 0.7879093632, 0.7886132852, 0.7890399285]

list_aupcr = [aupcr_32_2, aupcr_64_2, aupcr_128_2, aupcr_32_3, aupcr_64_3, aupcr_128_3, aupcr_32_4, aupcr_64_4, aupcr_128_4]

aupcr(list_aupcr, legend_comp_clients, 80)

# %% [markdown]
# 32

# %%
list_aupcr_32 = [aupcr_32_2, aupcr_32_3, aupcr_32_4]

aupcr(list_aupcr_32, legend_clients, 80)

# %% [markdown]
# 64

# %%
list_aupcr_64 = [aupcr_64_2, aupcr_64_3, aupcr_64_4]

aupcr(list_aupcr_64, legend_clients, 80)

# %% [markdown]
# 128

# %%
list_aupcr_128 = [aupcr_128_2, aupcr_128_3, aupcr_128_4]

aupcr(list_aupcr_128, legend_clients, 80)
